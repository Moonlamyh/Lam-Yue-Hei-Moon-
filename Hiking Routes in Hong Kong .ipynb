# %% [markdown]
# ## 1st Assignment
#
# - Name: Lam Yue Hei, Moon
# - Student ID: 21456550

# %% [markdown]
# Q1.

# %%
from bs4 import BeautifulSoup
import requests 
import pandas as pd
import numpy as np
from time import sleep
from time import time
from random import randint

# %%
#pick the language as English 
headers = {"Accept-Language": "en-US, en;q=0.5"}

#pick the url (hiking routes suggested by the government)
url = 'https://www.hiking.gov.hk/trail'
page = requests.get(url, headers = headers)
page
# Out:
# <Response [200]>

# %% [markdown]
# Q2(1).

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
#find the fist title
soup.find('title')
# Out:
# <title>Enjoy Hiking - Hiking Routes</title>

# %%
#find the h2
soup.find_all('h2')
# Out:
# []

# %% [markdown]
# Q2(2).

# %%
#find the text in the page
page.content
# Out:
# b'<!doctype html>\n\n<html class="no-js en-us font-md hide-hero index" lang="en-us" dir="ltr">\n  <head>\n      <meta charset="utf-8">\n      <meta http-equiv="x-ua-compatible" content="ie=edge">\n      <meta name="viewport" content="width=device-width, initial-scale=1.0">\n      <title>Enjoy Hiking - Hiking Routes</title>\n      <meta name="title" content="Enjoy Hiking - Hiking Routes">\n      <meta name="description" content="Hiking is taking a long walk in the countryside, usually for pleasure or exercise. There are many hiking trails in our Country Parks, and they are all managed by the Country and Marine Parks Authority. To manage hiking trails in remote areas is an extremely demanding task, so you can help by taking your litter home after hiking. To maintain the naturalness of our countryside, we promote the use of natural materials in our trails. Most concrete footpaths to remote villages which are linked with our footpaths are managed by the Home Affairs Department.">\n      <meta name="keywords" content="hiking trail, countryside, hong kong, family walks, nature trails, country trails, geo-trails, tree walks, long trails">\n      <meta property="fb:app_id" content="2016267315186642" />\n      <meta property="og:type" content="website" />\n      <meta property="og:url" content="https://www.hiking.gov.hk/trail/" />\n      <meta property="og:title" content="Enjoy Hiking - Hiking Routes" />\n      <meta property="og:description" content="Hiking is taking a long walk in the countryside, usually for pleasure or exercise. There are many hiking trails in our Country Parks, and they are all managed by the Country and Marine Parks Authority. To manage hiking trails in remote areas is an extremely demanding task, so you can help by taking your litter home after hiking. To maintain the naturalness of our countryside, we promote the use of natural materials in our trails. Most concrete footpaths to remote villages which are linked with our footpaths are managed by the Home Affairs Department." />\n      <meta property="og:image" content="https://www.hiking.gov.hk/public/static/assets/img/en-us/facebook_sharing.jpg" />\n      <meta property="og:image:width" content="1200" />\n      <meta property="og:image:height" content="600" />\n\n      <link rel="stylesheet" href="/public/static/assets/css/font-en-us.css">\n      <link rel="stylesheet" href="/public/static/vendor/bootstrap/css/bootstrap.min.css">\n      <link rel="stylesheet" href="/public/static/vendor/fontawesome/css/all.min.css">\n      <link rel=\'stylesheet\' href=\'/public/static/vendor/lazyload/jquery.lazyloadxt.fadein.min.css\' type=\'text/css\' media=\'all\' />\n      <link rel="stylesheet" href="/public/static/vendor/wow/libs/animate.css">\n      <link rel="stylesheet" href="/public/static/vendor/mdbootstrap/rating.min.css">\n      <link rel="stylesheet" href="/public/static/vendor/fancybox/jquery.fancybox.css">\n      <link rel="stylesheet" href="/public/static/vendor/swiper/swiper.min.css">\n      <link rel="stylesheet" href="/public/static/assets/css/layout.css">\n      <link rel="stylesheet" href="/public/static/assets/css/responsive.css">\n      <link rel="stylesheet" href="/public/static/assets/css/form.css">\n      <link rel="stylesheet" href="/public/static/assets/css/skin-v4.css">\n      <link rel="shortcut icon" href="/favicon.ico" />\n\n      <script>\n        var _domain = \'https://www.hiking.gov.hk\';\n        var _current_page = \'/trail\';\n        var _token = \'58ebc3e224a3f715cc6fa674f4ef8eb0787a20b1ca9772750ead83a2a7a062cd\';\n        var _lang = \'en-us\';\n        var swiper_button_prev_arialabel = "Previous slide";\n        var swiper_button_next_arialabel = "Next slide";\n        var swiper_goto = "Go to Slide ";\n        var swiper_slide = "";\n  \n        var fancy_close = "Close";\n        var fancy_next = "Next";\n        var fancy_prev = "Previous";\n        var fancy_error = "The requested content cannot be loaded.<br/>Please try again la ...

# %%
trails = soup.find (id = "grid-view")

# %% [markdown]
# Q4(1).

# %%
#get the element - names of the trails 
names = [day.text for day in trails.find_all(class_="f-sm-1dot25 text-white bg-third px-md-4 px-2 py-2 py-md-3 mb-0 view-info")]
names
# Out:
# ['Aberdeen Nature Trail',
#  'Aberdeen Tree Walk',
#  'Ap Chau Geosite',
#  "Bride's Pool Nature Trail",
#  'Cheung Sheung Country Trail',
#  'Chi Ma Wan Country Trail',
#  'Chuen Lung Family Walk',
#  'Chung Pui Tree Walk',
#  'Clear Water Bay Tree Walk',
#  'Double Haven Country Trail',
#  "Eagle's Nest Nature Trail",
#  'Fan Lau Country Trail',
#  'Fu Tei Country Trail',
#  'Fung Hang Family Walk',
#  'High Island Geo Trail',
#  'High Junk Peak Country Trail',
#  'Ho Pui Reservoir Family Walk',
#  'Hok Tau Country Trail',
#  'Hok Tau Reservoir Family Walk',
#  'Hong Kong Trail (Section 1)The Peak to Pok Fu Lam Reservoir Road',
#  'Hong Kong Trail (Section 2)Pok Fu Lam Reservoir Road to Peel Rise',
#  'Hong Kong Trail (Section 3) Peel Rise to Wan Chai Gap',
#  'Hong Kong Trail (Section 4)Wan Chai Gap to Wong Nai Chung Gap',
#  'Hong Kong Trail (Section 5)Wong Nai Chung Gap to Mount Parker Road',
#  'Hong Kong Trail (Section 6) Mount Parker Road to Tai Tam Road ',
#  'Hong Kong Trail (Section 7) Tai Tam Road to To Tei Wan',
#  'Hong Kong Trail (Section 8)To Tei Wan to Tai Long Wan',
#  'Hong Pak Country Trail ',
#  'Hung Mui Kuk Nature Trail',
#  'Kam Shan Family Walk',
#  'Kam Shan Tree Walk',
#  'Kap Lung Ancient Trail Country Trail',
#  'Kat O Heritage Trail',
#  'Kei Ling Ha Tree Walk',
#  'Keung Shan Country Trail',
#  'Lai Chi Chong Geosite',
#  'Lai Chi Wo Nature Trail',
#  'Lantau Trail (Section 1) Mui Wo to Nam Shan',
#  'Lantau Trail (Section 2) Nam Shan to Pak Kung Au',
#  'Lantau Trail (Section 3) Pak Kung Au to Ngong Ping',
#  'Lantau Trail (Section 4) Ngong Ping to Sham Wat Road',
#  'Lantau Trail (Section 5) Sham Wat Road to Man Cheung Po',
#  'Lantau Trail (Section 6)  Man Cheung Po to Tai O',
#  'Lantau Trail (Section 7) Tai O to Kau Ling Chung',
#  'Lantau Trail (Section 8) Kau Ling Chung to Shek Pik',
#  'Lantau Trail (Section 9) Shek Pik to Shui Hau',
#  'Lantau Trail (Section 10) Shui Hau to Old Tung Chung Road',
#  'Lantau Trail (Section 11) Tung Chung Road to Pui O',
#  'Lantau Trail (Section 12) Pui O to Mui Wo',
#  'Lau Shui Heung Country Trail',
#  'Lo Fu Tau Country Trail',
#  'Luk Wu Country Trail',
#  'Lung Ha Wan Country Trail',
#  'Lung Mun Country Trail',
#  'Ma On Shan Country Trail',
#  'Ma On Shan Family Walk',
#  'Ma Shi Chau Nature Trail',
#  'MacLehose Trail (Section 1)Pak Tam Chung to Long Ke',
#  'MacLehose Trail (Section 2)Long Ke to Pak Tam Au',
#  'MacLehose Trail (Section 3)Pak Tam Au to Kei Ling Ha',
#  "MacLehose Trail (Section 4)Kei Ling Ha to Tate's Cairn",
#  "MacLehose Trail (Section 5)Tate's Cairn to Tai Po Road",
#  'MacLehose Trail (Section 6)Tai Po Road to Shing Mun',
#  'MacLehose Trail (Section 7)Shing Mun to Lead Mine Pass',
#  'MacLehose Trail (Section 8) Lead Mine Pass to Route Twisk',
#  'MacLehose Trail (Section 9)Route Twisk to Tin Fu Tsai',
#  'MacLehose Trail (Section 10)Tin Fu Tsai to Tuen Mun',
#  'Nai Chung Tree Walk',
#  'Nam Chung Country Trail',
#  'Nam Shan Tree Walk',
#  'Nei Lak Shan Country Trail',
#  'Ngong Ping Tree Walk',
#  'Pak Tam Chung Family Walk',
#  'Pak Tam Chung Nature Trail',
#  'Pak Tam Chung to Biu Tsim Kok Hiking Trail',
#  'Pak Tam Chung Tree Walk',
#  'Pak Tam Country Trail',
#  'Pat Sin Leng Nature Trail',
#  'Peak Trail (High West Section)',
#  'Peak Trail (Pinewood Battery Section)',
#  'Pineapple Dam Nature Trail',
#  'Pinewood Battery Heritage Trail',
#  'Ping Chau Country Trail',
#  'Plover Cove Reservoir Country Trail',
#  'Pok Fu Lam Family Walk',
#  'Pok Fu Lam Tree Walk',
#  'Pottinger Peak Country Trail',
#  'Quarry Bay Tree Walk',
#  'Rotary Park Nature Trail',
#  'Sharp Island Geo Trail',
#  'Shek Pik Country Trail',
#  'Sheung Yiu Country Trail',
#  'Sheung Yiu Family Walk',
#  'South Lantau Country Trail',
#  'Tai Lam Chung Country Trail',
#  'Tai Lam Nature Trail',
#  'Tai Long Wan Hiking Trail',
#  'Tai Mei Tuk Family Walk',
#  'Tai Mo Shan Family Walk',
#  'Tai Po Kau Nature Trail',
#  'Tai Tam Country Trail',
#  'Tai Tam Family Walk',
#  'Tai Tam Tree Walk',
#  'Tai Tan Country Trail',
#  'Tai Tan Tree Walk',
#  'Tai Tong Nature Trail',
#  'Tai Tong Tree Walk',
#  'Tei Tong Tsai Country Trail',
#  'Tsiu Hang Nature Trail',
#  'Twisk Nature Trail',
#  'War Relics Trail (Lion Rock and Ma On Shan)',
#  'War Relics Trail (Shing Mun)',
#  'Wilson Trail (Section 1) Stanley Gap Road to Wong Nai Chung Reservoir',
#  'Wilson Trail (Section 2)Wong Nai Chung Reservoir to Lam Tin',
#  'Wilson Trail (Section 3) Lam Tin to Tseng Lan Shue',
#  'Wilson Trail (Section 4)Tseng Lan Shue to Sha Tin Pass',
#  'Wilson Trail (Section 5)Sha Tin Pass to Tai Po Road',
#  'Wilson Trail (Section 6) Tai Po Road to Shing Mun Reservoir',
#  'Wilson Trail (Section 7)Shing Mun Reservoir to Yuen Tun Ha',
#  'Wilson Trail (Section 8) Yuen Tun Ha to Cloudy Hill',
#  'Wilson Trail (Section 9)Cloudy Hill to Pat Sin Leng',
#  'Wilson Trail (Section 10)Pat Sin Leng to Nam Chung',
#  'Wong Lung Hang Country Trail',
#  'Wong Nai Chung Tree Walk',
#  'Wong Shek Family Walk',
#  'Wong Shek Tree Walk',
#  'Wu Kau Tang Country Trail',
#  'Yuen Tsuen Ancient Trail Country Trail ',
#  'Yuen Tun Country Trail']

# %%
#get the districts
districts = [sd.text for sd in trails.find_all(class_="text-red px-md-4 px-2 py-1 bg-forth mb-0 region")]
districts
# Out:
# ['Hong Kong Island',
#  'Hong Kong Island',
#  'North New Territories',
#  'North New Territories',
#  'Sai Kung',
#  'Lantau',
#  'West New Territories',
#  'North New Territories',
#  'Sai Kung',
#  'North New Territories',
#  'Central New Territories',
#  'Lantau',
#  'West New Territories',
#  'North New Territories',
#  'Sai Kung',
#  'Sai Kung',
#  'West New Territories',
#  'North New Territories',
#  'North New Territories',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Central New Territories',
#  'Central New Territories',
#  'Central New Territories',
#  'West New Territories',
#  'North New Territories',
#  'Sai Kung',
#  'Lantau',
#  'Sai Kung',
#  'North New Territories',
#  'Lantau',
#  'Lantau',
#  'Lantau',
#  'Lantau',
#  'Lantau',
#  'Lantau',
#  'Lantau',
#  'Lantau',
#  'Lantau',
#  'Lantau',
#  'Lantau',
#  'Lantau',
#  'North New Territories',
#  'Lantau',
#  'Sai Kung',
#  'Sai Kung',
#  'West New Territories',
#  'Central New Territories',
#  'Central New Territories',
#  'North New Territories',
#  'Sai Kung',
#  'Sai Kung',
#  'Sai Kung',
#  'Sai Kung',
#  'Central New Territories',
#  'Central New Territories',
#  'Central New Territories',
#  'Central New Territories',
#  'West New Territories',
#  'West New Territories',
#  'Central New Territories',
#  'North New Territories',
#  'Lantau',
#  'Lantau',
#  'Lantau',
#  'Sai Kung',
#  'Sai Kung',
#  'Sai Kung',
#  'Sai Kung',
#  'Sai Kung',
#  'North New Territories',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Central New Territories',
#  'Hong Kong Island',
#  'North New Territories',
#  'North New Territories',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'West New Territories',
#  'Sai Kung',
#  'Lantau',
#  'Sai Kung',
#  'Sai Kung',
#  'Lantau',
#  'West New Territories',
#  'West New Territories',
#  'Sai Kung',
#  'North New Territories',
#  'West New Territories',
#  'North New Territories',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Sai Kung',
#  'Sai Kung',
#  'West New Territories',
#  'West New Territories',
#  'Lantau',
#  'Sai Kung',
#  'West New Territories',
#  'Central New Territories',
#  'Central New Territories',
#  'Hong Kong Island',
#  'Hong Kong Island',
#  'Sai Kung',
#  'Central New Territories',
#  'Central New Territories',
#  'Central New Territories',
#  'Central New Territories',
#  'North New Territories',
#  'North New Territories',
#  'North New Territories',
#  'Lantau',
#  'Hong Kong Island',
#  'Sai Kung',
#  'Sai Kung',
#  'North New Territories',
#  'West New Territories',
#  'West New Territories']

# %%
# get the rating of challenge and love
difficulties = [temp.text for temp in trails.find_all(class_="d-block text-center")]
difficulties
# Out:
# ['(1-Star Easy)',
#  '(Rating 1-Heart)',
#  '(1-Star Easy)',
#  '(Rating 4-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 4-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 4-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 2-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 2-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 5-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 2-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 4-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 4-Heart)',
#  '(1-Star Easy)',
#  '(Rating 2-Heart)',
#  '(1-Star Easy)',
#  '(Rating 4-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 5-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 4-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 4-Heart)',
#  '(1-Star Easy)',
#  '(Rating 4-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 4-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 4-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 4-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 4-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 4-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 5-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 2-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 4-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 4-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 4-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 4-Heart)',
#  '(1-Star Easy)',
#  '(Rating 1-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 4-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 4-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 3-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 4-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 2-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 4-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 1-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 4-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 403487-Heart)',
#  '(1-Star Easy)',
#  '(Rating 1-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 5-Heart)',
#  '(1-Star Easy)',
#  '(Rating 5-Heart)',
#  '(1-Star Easy)',
#  '(Rating 5-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 5-Heart)',
#  '(1-Star Easy)',
#  '(Rating 4-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 4-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 4-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 2-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 4-Heart)',
#  '(5-Star Very Difficult)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 2-Heart)',
#  '(1-Star Easy)',
#  '(Rating 5-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 4-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 5-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 4-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 4-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 4-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 4-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 5-Heart)',
#  '(1-Star Easy)',
#  '(Rating 5-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 5-Heart)',
#  '(1-Star Easy)',
#  '(Rating 5-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 5-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 5-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 5-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 2-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 2-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 3-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 3-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 4-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 5-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 4-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 3-Heart)',
#  '(1-Star Easy)',
#  '(Rating 5-Heart)',
#  '(2-Star Moderate)',
#  '(Rating 3-Heart)',
#  '(4-Star Difficult)',
#  '(Rating 4-Heart)',
#  '(3-Star Demanding)',
#  '(Rating 2-Heart)']

# %% [markdown]
# Q4(2).

# %%
#As rating for both challenge and heart are different, 
#this code is to seperate them into two lists by identifying the word "star" in rating difficulties

challenge = []
rating = []

for d in difficulties: 
    if "Star" in d: 
        challenge.append(d)
    else: 
        rating.append(d)

print(challenge)
print(rating)
# Out:
# ['(1-Star Easy)', '(1-Star Easy)', '(1-Star Easy)', '(1-Star Easy)', '(2-Star Moderate)', '(4-Star Difficult)', '(1-Star Easy)', '(1-Star Easy)', '(1-Star Easy)', '(3-Star Demanding)', '(1-Star Easy)', '(1-Star Easy)', '(2-Star Moderate)', '(1-Star Easy)', '(2-Star Moderate)', '(3-Star Demanding)', '(1-Star Easy)', '(2-Star Moderate)', '(1-Star Easy)', '(2-Star Moderate)', '(2-Star Moderate)', '(2-Star Moderate)', '(2-Star Moderate)', '(3-Star Demanding)', '(2-Star Moderate)', '(2-Star Moderate)', '(3-Star Demanding)', '(2-Star Moderate)', '(1-Star Easy)', '(1-Star Easy)', '(1-Star Easy)', '(2-Star Moderate)', '(2-Star Moderate)', '(1-Star Easy)', '(3-Star Demanding)', '(1-Star Easy)', '(1-Star Easy)', '(1-Star Easy)', '(4-Star Difficult)', '(4-Star Difficult)', '(2-Star Moderate)', '(3-Star Demanding)', '(2-Star Moderate)', '(3-Star Demanding)', '(2-Star Moderate)', '(2-Star Moderate)', '(2-Star Moderate)', '(2-Star Moderate)', '(3-Star Demanding)', '(3-Star Demanding)', '(2-Star Moderate)', '(3-Star Demanding)', '(2-Star Moderate)', '(3-Star Demanding)', '(2-Star Moderate)', '(1-Star Easy)', '(1-Star Easy)', '(3-Star Demanding)', '(4-Star Difficult)', '(4-Star Difficult)', '(4-Star Difficult)', '(3-Star Demanding)', '(2-Star Moderate)', '(3-Star Demanding)', '(4-Star Difficult)', '(2-Star Moderate)', '(4-Star Difficult)', '(1-Star Easy)', '(3-Star Demanding)', '(1-Star Easy)', '(2-Star Moderate)', '(1-Star Easy)', '(1-Star Easy)', '(1-Star Easy)', '(3-Star Demanding)', '(1-Star Easy)', '(1-Star Easy)', '(2-Star Moderate)', '(2-Star Moderate)', '(2-Star Moderate)', '(1-Star Easy)', '(1-Star Easy)', '(2-Star Moderate)', '(5-Star Very Difficult)', '(1-Star Easy)', '(1-Star Easy)', '(2-Star Moderate)', '(1-Star Easy)', '(1-Star Easy)', '(1-Star Easy)', '(3-Star Demanding)', '(2-Star Moderate)', '(1-Star Easy)', '(3-Star Demanding)', '(3-Star Demanding)', '(3-Star Demanding)', '(4-Star Difficult)', '(1-Star Easy)', '(1-Star Easy)', '(2-Star Moderate)', '(3-Star Demanding)', '(1-Star Easy)', '(1-Star Easy)', '(2-Star Moderate)', '(1-Star Easy)', '(2-Star Moderate)', '(1-Star Easy)', '(1-Star Easy)', '(1-Star Easy)', '(1-Star Easy)', '(3-Star Demanding)', '(1-Star Easy)', '(3-Star Demanding)', '(3-Star Demanding)', '(3-Star Demanding)', '(3-Star Demanding)', '(2-Star Moderate)', '(2-Star Moderate)', '(3-Star Demanding)', '(4-Star Difficult)', '(4-Star Difficult)', '(4-Star Difficult)', '(3-Star Demanding)', '(1-Star Easy)', '(1-Star Easy)', '(1-Star Easy)', '(2-Star Moderate)', '(4-Star Difficult)', '(3-Star Demanding)']
# ['(Rating 1-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 2-Heart)', '(Rating 2-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 5-Heart)', '(Rating 3-Heart)', '(Rating 2-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 2-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 5-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 4-Heart)', '(Rating 4-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 4-Heart)', '(Rating 5-Heart)', '(Rating 2-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 1-Heart)', '(Rating 4-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 2-Heart)', '(Rating 4-Heart)', '(Rating 1-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 403487-Heart)', '(Rating 1-Heart)', '(Rating 5-Heart)', '(Rating 5-Heart)', '(Rating 5-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 5-Heart)', '(Rating 4-Heart)', '(Rating 4-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 2-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 2-Heart)', '(Rating 5-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 5-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 4-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 5-Heart)', '(Rating 5-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 5-Heart)', '(Rating 5-Heart)', '(Rating 3-Heart)', '(Rating 5-Heart)', '(Rating 3-Heart)', '(Rating 5-Heart)', '(Rating 3-Heart)', '(Rating 5-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 2-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 2-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 5-Heart)', '(Rating 4-Heart)', '(Rating 3-Heart)', '(Rating 3-Heart)', '(Rating 5-Heart)', '(Rating 3-Heart)', '(Rating 4-Heart)', '(Rating 2-Heart)']

# %%
#find the descriptions of the trails 
descriptions = [sd.text for sd in trails.find_all(class_="summary d-block px-md-2 px-0 pt-2")]
descriptions
# Out:
# ['\n                                    The first leg of Aberdeen Nature Trail skirts along Lower Ab...                                ',
#  '\n                                    Aberdeen Tree Walk lies near the downtown area and takes abo...                                ',
#  '\n                                    Located to the east of Sha Tau Kok, Ap Chau, which literally...                                ',
#  '\n                                    Located at the northwestern corner of Plover Cove Country Pa...                                ',
#  '\n                                    Cheung Sheung, surrounded by steep spurs, is one of those ra...                                ',
#  '\n                                    Chi Ma Wan Country Trail, with a total distance of 18.5 kilo...                                ',
#  '\n                                    Situated on a mountain in Tsuen Wan, Chuen Lung is an ancien...                                ',
#  '\n                                    Chung Pui Tree Walk is a circular route with 0.25km in lengt...                                ',
#  '\n                                    Clear Water Bay Tree Walk is cutting across dense woodlands ...                                ',
#  '\n                                    Some people say the history of Hong Kong is all about migrat...                                ',
#  '\n                                    Eagle&rsquo;s Nest, also known as Tsim Shan, is located insi...                                ',
#  '\n                                    The multicultural facet of Hong Kong could be manifested in ...                                ',
#  '\n                                    For the many places whose historical side has been swallowed...                                ',
#  '\n                                    Visitors are a rarity in many border regions, but it is thes...                                ',
#  '\n                                    Geological wonders are not necessarily situated on remote ou...                                ',
#  '\n                                    Soaring at an altitude of 344 metres with pointed edges, Hig...                                ',
#  '\n                                    Located inside Tai Lam Country Park, Ho Pui Reservoir is an ...                                ',
#  '\n                                    Offering a rare but pastoral scene with many farmhouses and ...                                ',
#  '\n                                    Located inside Pat Sin Leng Country Park, Hok Tau Reservoir ...                                ',
#  '\n                                    The bird’s eye view of Victoria Harbour from Victoria Peak i...                                ',
#  '\n                                    The second leg of the Hong Kong Trail starts at Pok Fu Lam R...                                ',
#  '\n                                    Street names in Hong Kong provide a window into the history ...                                ',
#  '\n                                    If there is a place to learn all about the flora and the his...                                ',
#  '\n                                    Section 5 of the trail begins at Wong Nai Chung Reservoir. &...                                ',
#  '\n                                    Section 6 of the Hong Kong Trail starts at Quarry Gap at an ...                                ',
#  '\n                                    Section 7 is one of the easiest sections of the entire Hong ...                                ',
#  '\n                                    Hong Kong Island is surrounded by sea, so stretches of coast...                                ',
#  '\n                                    Situated around Quarry Bay and Tai Koo Shing, Hong Pak Count...                                ',
#  '\n                                    Between spring and summer, visitors to Hung Mui Kuk are boun...                                ',
#  '\n                                    Monkeys in Hong Kong do not live in Water Curtain Cave; most...                                ',
#  '\n                                    Kam Shan Tree Walk is located in Kam Shan Country Park, with...                                ',
#  '\n                                    With its name originating from Kap Lung Village, Kap Lung An...                                ',
#  '\n                                    Kat O is the biggest island in the northeast New Territories...                                ',
#  '\n                                    Kei Ling Ha Tree Walk is located in Ma On Shan Country Park ...                                ',
#  '\n                                    Keung Shan Country Trail goes down south at Fan Shui Au befo...                                ',
#  '\n                                    Roaming the countryside has become an escape from the hustle...                                ',
#  '\n                                    Located in the Double Haven Geo-Area, Lai Chi Wo Nature Trai...                                ',
#  '\n                                    The first leg of the Lantau Trail runs parallel to South Lan...                                ',
#  '\n                                    Adorned with a seemingly limitless sea of silvergrass at an ...                                ',
#  '\n                                    Before Hong Kong became a city and port, Lantau Peak had alw...                                ',
#  '\n                                    Section 4 begins at Ngong Ping, where the Wisdom Path, a lan...                                ',
#  '\n                                    Start your hike at the trail behind the pavilion at the junc...                                ',
#  '\n                                    Hailed as the Venice of Hong Kong, Tai O is a fishing port s...                                ',
#  '\n                                    The longest of all of the Lantau Trail, this section begins ...                                ',
#  '\n                                    The picturesque Kau Ling Chung Campsite marks the start poin...                                ',
#  '\n                                    The local countryside is defined by a mixture of half artifi...                                ',
#  '\n                                    If you are like any city dwellers who always want a weekend ...                                ',
#  '\n                                    As the easiest section of the Lantau Trail, Section 11 begin...                                ',
#  '\n                                    The end of the trip to the seaside between Section 7 and Sec...                                ',
#  '\n                                    Lau Shui Heung, a feast for the eyes and ears, certainly liv...                                ',
#  '\n                                    Literally translated as ‘Get rid of fleas on a tiger’s head’...                                ',
#  '\n                                    It is not uncommon to think of trails near the water during ...                                ',
#  '\n                                    Lung Ha Wan Country Trail is well equipped with recreational...                                ',
#  '\n                                    Every hike at Lung Mun Country Trail starts with "eating", a...                                ',
#  '\n                                    With rich deposits of magnetite and haematite in the granite...                                ',
#  '\n                                    Ma On Shan Family Walk is located on the hillside of Ma On S...                                ',
#  '\n                                    Ma Shi Chau Nature Trail is located in the Ma Shi Chau Speci...                                ',
#  '\n                                    Many people are envious of the beaches overseas, which are a...                                ',
#  '\n                                    MacLehose Trail Section 2 is one of the phenomenally popular...                                ',
#  '\n                                    Featuring undulating mountains with a steep gradient, the th...                                ',
#  '\n                                    The fourth section of the MacLehose Trail is another gateway...                                ',
#  '\n                                    The MacLehose Trail spreads over many mountains, with its fi...                                ',
#  '\n                                    The sixth section is the shortest and easiest section of the...                                ',
#  '\n                                    Shing Mun Reservoir was built in 1937. Its main dam, steel b...                                ',
#  '\n                                    Hong Kong used to have many mine sites, one of which was Lea...                                ',
#  '\n                                    There is an observation deck soon after the trail starts. Th...                                ',
#  '\n                                    The last section MacLehose Trail is the lengthiest one, cros...                                ',
#  '\n                                    Nai Chung Tree Walk is located in the Nai Chung Barbecue Sit...                                ',
#  '\n                                    Situated close to the north eastern border, Nam Chung does n...                                ',
#  '\n                                    Nam Shan Tree Walk is 440m long, passing through the Section...                                ',
#  '\n                                    Nei Lak Shan Country Trail, a level circular path, starts at...                                ',
#  '\n                                    Ngong Ping Plateau is humid and foggy all year round. Its fe...                                ',
#  '\n                                    Located at the entrance of Sai Kung Country Park, Pak Tam Ch...                                ',
#  '\n                                    Pak Tam Chung Nature Trail is built along the river, offerin...                                ',
#  '\n                                    The section between Pak Tam Chung and the East Dam at High I...                                ',
#  '\n                                    Located in Sai Kung West Country Park, Pak Tam Chung Tree Wa...                                ',
#  '\n                                    An ancient village path connecting Pak Tam Au and Pak Tam Ch...                                ',
#  '\n                                    Pat Sin Leng, an important mountain range in North East New ...                                ',
#  '\n                                    Legend has it that early inhabitants of Hong Kong Island fou...                                ',
#  '\n                                    Legend has it that early inhabitants of Hong Kong Island fou...                                ',
#  '\n                                    Hong Kong iconic food item pineapple bun contains no pineapp...                                ',
#  '\n                                    Located inside Lung Fu Shan Country Park, the Pinewood Batte...                                ',
#  '\n                                    Situated at the northeasternmost side of Hong Kong, Ping Cha...                                ',
#  '\n                                    Completed in 1968, Plover Cove Reservoir is the second large...                                ',
#  '\n                                    How far is the countryside from the city? In the case of Pok...                                ',
#  '\n                                    Pok Fu Lam Tree Walk is the first Hong Kong tree walk featur...                                ',
#  '\n                                    If you are looking for a level route that can be accessed ea...                                ',
#  '\n                                    Quarry Bay Tree Walk is a comfortable and peaceful route, co...                                ',
#  '\n                                    The Rotary Park Nature Trail is the perfect place for childr...                                ',
#  '\n                                    Located in Port Shelter, Sai Kung, Sharp Island is connected...                                ',
#  '\n                                    The country trail begins at Wisdom Path, Ngong Ping, a lands...                                ',
#  '\n                                    Merging with Pak Tam Chung Nature Trail, Sheung Yiu Country ...                                ',
#  '\n                                    Sheung Yiu Family Walk is an attractive place where everythi...                                ',
#  '\n                                    South Lantau Country Trail begins in Nam Shan and its hillsi...                                ',
#  '\n                                    To enjoy the scenic beauty of Yuen Long, the best way is to ...                                ',
#  '\n                                    Having the longest span among all other nature trails in the...                                ',
#  '\n                                    Starting at Sai Wan Pavilion, this immensely popular hiking ...                                ',
#  '\n                                    Tai Mei Tuk is located on a promontory of Plover Cove, which...                                ',
#  '\n                                    Located inside Rotary Park, Tai Mo Shan Family Walk is a cir...                                ',
#  '\n                                    If you want to explore the rich biodiversity of forests, the...                                ',
#  '\n                                    Not only does Tai Tam Country Trail offer a getaway from the...                                ',
#  '\n                                    Hiking trails in Hong Kong are an oasis of serenity in the u...                                ',
#  '\n                                    Tai Tam Tree Walk is about 70m in length, which is the short...                                ',
#  '\n                                    Hong Kong, surrounded by water on three sides, possesses cle...                                ',
#  '\n                                    Tai Tan Tree Walk is a circular route with a length of 230m....                                ',
#  '\n                                    It would be no exaggeration to say that Tai Tong Sweet Gum W...                                ',
#  '\n                                    Adjacent to Tai Tong BBQ Site No.1, Tai Lam Country Park, Ta...                                ',
#  '\n                                    Has the question of the location of the renowned Po Lam Mona...                                ',
#  '\n                                    Located inside the AFCD Lions Nature Education Centre, Tsiu ...                                ',
#  '\n                                    If you take a look at photos taken in the 19th century, you ...                                ',
#  '\n                                    Some 80 years ago, Hong Kong witnessed the Battle of Hong Ko...                                ',
#  '\n                                    Many military relics of the Second World War in Hong Kong ha...                                ',
#  '\n                                    The uphill slopes on the Wilson Trail are too many to count,...                                ',
#  '\n                                    The hiking trail starts from Hong Kong Parkview and is next ...                                ',
#  '\n                                    The Wilson Trail spans Hong Kong Island, Kowloon and the New...                                ',
#  '\n                                    Victoria Peak is known as one of the best spots to enjoy the...                                ',
#  '\n                                    If you are an amateur hiker or looking for a family-friendly...                                ',
#  '\n                                    Traversing Kowloon Reservoir and Shing Mun Reservoir, Sectio...                                ',
#  '\n                                    Boasting majestic mountain scenery paired with magnificent r...                                ',
#  '\n                                    Section 8 does not fall within the area of country parks and...                                ',
#  '\n                                    Section 9 starts from the summit of Cloudy Hill and ends in ...                                ',
#  '\n                                    The last section is a scenic route as well as an easy hike. ...                                ',
#  '\n                                    To embark on the journey, hikers set off in Tung Chung and p...                                ',
#  '\n                                    Wong Nai Chung Tree Walk runs between the sections of Sir Ce...                                ',
#  '\n                                    Hailed as the ‘backyard of Hong Kong’, Sai Kung is a place o...                                ',
#  '\n                                    Wong Shek Tree Walk is located in Sai Kung East Country Park...                                ',
#  '\n                                    Feng Shui and numerology play an important role in Chinese c...                                ',
#  '\n                                    Ancient trails used to be a key route for villagers to commu...                                ',
#  '\n                                    The Hakka form an integral part of indigenous residents of H...                                ']

# %% [markdown]
# Q4(3).

# %%
#make sure all elements have the same lens
print(len(names))
print(len(districts))
print(len(challenge))
print(len(rating))
print(len(new))
# Out:
# 129
# 129
# 129
# 129
# 129

# %%
#create data frame
places = pd.DataFrame({
 "Names": names,
 "Districts": districts,
 "Difficulties - Over 5 Stars": challenge,
 "Rating - Over 5 Stars": rating,
 "Descriptions": new
})
places
# Out:
#                                        Names              Districts  \
# 0                      Aberdeen Nature Trail       Hong Kong Island
# 1                         Aberdeen Tree Walk       Hong Kong Island
# 2                            Ap Chau Geosite  North New Territories
# 3                  Bride's Pool Nature Trail  North New Territories
# 4                Cheung Sheung Country Trail               Sai Kung
# ..                                       ...                    ...
# 124                    Wong Shek Family Walk               Sai Kung
# 125                      Wong Shek Tree Walk               Sai Kung
# 126                Wu Kau Tang Country Trail  North New Territories
# 127  Yuen Tsuen Ancient Trail Country Trail    West New Territories
# 128                   Yuen Tun Country Trail   West New Territories
#
#     Difficulties - Over 5 Stars Rating - Over 5 Stars  \
# 0                 (1-Star Easy)      (Rating 1-Heart)
# 1                 (1-Star Easy)      (Rating 4-Heart)
# 2                 (1-Star Easy)      (Rating 3-Heart)
# 3                 (1-Star Easy)      (Rating 3-Heart)
# 4             (2-Star Moderate)      (Rating 3-Heart)
# ..                          ...                   ...
# 124               (1-Star Easy)      (Rating 3-Heart)
# 125               (1-Star Easy)      (Rating 5-Heart)
# 126           (2-Star Moderate)      (Rating 3-Heart)
# 127          (4-Star Difficult)      (Rating 4-Heart)
# 128          (3-Star Demanding)      (Rating 2-Heart)
#
#                                           Descriptions
# 0    The first leg of Aberdeen Nature Trail skirts ...
# 1    Aberdeen Tree Walk lies near the downtown area...
# 2    Located to the east of Sha Tau Kok, Ap Chau, w...
# 3    Located at the northwestern corner of Plover C...
# 4    Cheung Sheung, surrounded by steep spurs, is o...
# ..                                                 ...
# 124  Hailed as the ‘backyard of Hong Kong’, Sai Kun...
# 125  Wong Shek Tree Walk is located in Sai Kung Eas...
# 126  Feng Shui and numerology play an important rol...
# 127  Ancient trails used to be a key route for vill...
# 128  The Hakka form an integral part of indigenous ...
#
# [129 rows x 5 columns]

# %% [markdown]
# Q4(3).

# %%
#save it to my laptop(with window setting) 
places.to_csv(r'C:\Users\Moon Lam\Desktop\Master\AIDM 7330\places.csv', index = False)

# %% [markdown]
# The problem I define is https://www.hiking.gov.hk/trail, a government official website, sharing the
# hiking routes and information about hiking in Hong Kong.
#
# In the code, I scrape the webpage in English, finding titles and useful elements. I scrape all the
# information about hiking routes. It includes the hiking trail names, districts, difficulties, rating, and
# descriptions.
#
# However, the difficulties and rating of trails are in the same class on the webpage. I use the for loop
# and conditional statements to separate the elements by identifying the word “stars” as difficulties.
# Meanwhile, there are “\n” and several spaces at the beginning of the descriptions. I use for loop
# again to beautify the trail descriptions.
#
# I create a data frame that shares the information of the hiking trails with the output as a CSV file.
# There are 5 columns (without index) and 129 rows, meaning that there are 129 trails in total. Each
# column represents trails’ name, district, difficulties (with five as full marks), ratings (with five as full
# marks), and descriptions. Each row means each trail. It is sorted by the trail names in alphabetical
# order, the same as the webpage.
#
# Despite that, there are still some bugs in the data frame. First, the number of symbols of hearts or
# stars might be different from that in text. For example, there are only three hearts in ratings of
# Aberdeen Tree Walk, but it has written “Rating 4-Heart”, reducing the accuracy of the data. Also, the
# descriptions of the trails end with “...”, which has not shown the complete description but only a
# summary.
